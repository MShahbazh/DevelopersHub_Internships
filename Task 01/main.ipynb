# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(f"SHAPE : {df.shape}")
print(f"COLUMNS : {df.columns}")
print(f"FIRST 5 ROWS : \n{df.head(5)}")
print(f"INFO : \n{df.info}")
print(f"DESCRIBE : \n{df.describe}")
# Out:
# DESCRIBE :
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
sns.scatterplot(data=df,x='sepal_length',y='sepal_width')
plt.show()

# %%
sns.scatterplot(data=df,x='petal_length',y='petal_width')
plt.show()

# %%
sns.histplot(data=df,x='petal_length',color='red')
sns.histplot(data=df,x='petal_width',color='blue')
plt.plot()
# Out:
# []

# %%
sns.histplot(data=df,x='sepal_length',color='black')
sns.histplot(data=df,x='sepal_width',color='pink')
plt.show()

# %%
sns.boxplot(data=df,x='sepal_length')
plt.show()

# %%
sns.boxplot(data=df,x='sepal_width')
plt.show()

# %%
sns.boxplot(data=df,x='petal_length')
plt.show()

# %%
sns.boxplot(data=df,x='petal_width')
plt.show()
